# %% [markdown]
# # Real-ESRGAN Inference Demo
#
# [![arXiv](https://img.shields.io/badge/arXiv-Paper-<COLOR>.svg)](https://arxiv.org/abs/2107.10833)
# [![GitHub Stars](https://img.shields.io/github/stars/xinntao/Real-ESRGAN?style=social)](https://github.com/xinntao/Real-ESRGAN)
# [![download](https://img.shields.io/github/downloads/xinntao/Real-ESRGAN/total.svg)](https://github.com/xinntao/Real-ESRGAN/releases)
#
# This is a **Practical Image Restoration Demo** of our paper [''Real-ESRGAN: Training Real-World Blind Super-Resolution with Pure Synthetic Data''](https://arxiv.org/abs/2107.10833).
# We extend the powerful ESRGAN to a practical restoration application (namely, Real-ESRGAN), which is trained with pure synthetic data. <br>
# The following figure shows some real-life examples.
#
# <img src="https://raw.githubusercontent.com/xinntao/Real-ESRGAN/master/assets/teaser.jpg" width="100%">
#
# We provide a pretrained model (*RealESRGAN_x4plus.pth*) with upsampling X4.<br>
# **Note that RealESRGAN may still fail in some cases as the real-world degradations are really too complex.**<br>
# Moreover, it **may not** perform well on **human faces, text**, *etc*, which will be optimized later.
# <br>
#
# You can also find a **Portable Windows/Linux/MacOS executable files for Intel/AMD/Nvidia GPU.** in our [GitHub repo](https://github.com/xinntao/Real-ESRGAN). <br>
# This executable file is **portable** and includes all the binaries and models required. No CUDA or PyTorch environment is needed.<br>
# This executable file is based on the wonderful [Tencent/ncnn](https://github.com/Tencent/ncnn).

# %% [markdown]
# # 1. Preparations
# For Google Colab
# Before start, make sure that you choose
# * Runtime Type = Python 3
# * Hardware Accelerator = GPU
#
# in the **Runtime** menu -> **Change runtime type**
#
# Then, we clone the repository, set up the envrironment.

# %%
# Clone Real-ESRGAN and enter the Real-ESRGAN
# !git clone https://github.com/xinntao/Real-ESRGAN.git
# %cd Real-ESRGAN

# If you already have a clone, just go to it
# %cd ../../../Real-ESRGAN
# Set up the environment
# !pip install basicsr
# !pip install facexlib
# !pip install gfpgan
# !pip install -r requirements.txt
# !python setup.py develop
# !python -m pip install torch==2.0.1 torchvision==0.15.2 --extra-index-url https://download.pytorch.org/whl/cu118
# Out:
# C:\Users\lamch\Repo\Real-ESRGAN
# Requirement already satisfied: basicsr in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (1.4.2)
# Requirement already satisfied: addict in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from basicsr) (2.4.0)
# Requirement already satisfied: future in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from basicsr) (1.0.0)
# Requirement already satisfied: lmdb in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from basicsr) (1.5.1)
# Requirement already satisfied: numpy>=1.17 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from basicsr) (1.24.4)
# Requirement already satisfied: opencv-python in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from basicsr) (4.10.0.84)
# Requirement already satisfied: Pillow in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from basicsr) (10.4.0)
# Requirement already satisfied: pyyaml in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from basicsr) (6.0.2)
# Requirement already satisfied: requests in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from basicsr) (2.32.3)
# Requirement already satisfied: scikit-image in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from basicsr) (0.21.0)
# Requirement already satisfied: scipy in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from basicsr) (1.10.1)
# Requirement already satisfied: tb-nightly in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from basicsr) (2.14.0a20230808)
# Requirement already satisfied: torch>=1.7 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from basicsr) (2.0.1+cu118)
# Requirement already satisfied: torchvision in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from basicsr) (0.15.2+cu118)
# Requirement already satisfied: tqdm in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from basicsr) (4.66.5)
# Requirement already satisfied: yapf in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from basicsr) (0.40.2)
# Requirement already satisfied: filelock in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from torch>=1.7->basicsr) (3.16.1)
# Requirement already satisfied: typing-extensions in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from torch>=1.7->basicsr) (4.11.0)
# Requirement already satisfied: sympy in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from torch>=1.7->basicsr) (1.13.3)
# Requirement already satisfied: networkx in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from torch>=1.7->basicsr) (3.1)
# Requirement already satisfied: jinja2 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from torch>=1.7->basicsr) (3.1.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from requests->basicsr) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from requests->basicsr) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from requests->basicsr) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from requests->basicsr) (2024.8.30)
# Requirement already satisfied: imageio>=2.27 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from scikit-image->basicsr) (2.35.1)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from scikit-image->basicsr) (2023.7.10)
# Requirement already satisfied: PyWavelets>=1.1.1 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from scikit-image->basicsr) (1.4.1)
# Requirement already satisfied: packaging>=21 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from scikit-image->basicsr) (24.1)
# Requirement already satisfied: lazy_loader>=0.2 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from scikit-image->basicsr) (0.4)
# Requirement already satisfied: absl-py>=0.4 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from tb-nightly->basicsr) (2.1.0)
# Requirement already satisfied: grpcio>=1.48.2 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from tb-nightly->basicsr) (1.67.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from tb-nightly->basicsr) (2.35.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from tb-nightly->basicsr) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from tb-nightly->basicsr) (3.7)
# Requirement already satisfied: protobuf>=3.19.6 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from tb-nightly->basicsr) (5.28.2)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from tb-nightly->basicsr) (75.1.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from tb-nightly->basicsr) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from tb-nightly->basicsr) (3.0.4)
# Requirement already satisfied: wheel>=0.26 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from tb-nightly->basicsr) (0.44.0)
# Requirement already satisfied: colorama in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from tqdm->basicsr) (0.4.6)
# Requirement already satisfied: importlib-metadata>=6.6.0 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from yapf->basicsr) (7.0.1)
# Requirement already satisfied: platformdirs>=3.5.1 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from yapf->basicsr) (3.10.0)
# Requirement already satisfied: tomli>=2.0.1 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from yapf->basicsr) (2.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from google-auth<3,>=1.6.3->tb-nightly->basicsr) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from google-auth<3,>=1.6.3->tb-nightly->basicsr) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from google-auth<3,>=1.6.3->tb-nightly->basicsr) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from google-auth-oauthlib<1.1,>=0.5->tb-nightly->basicsr) (2.0.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from importlib-metadata>=6.6.0->yapf->basicsr) (3.20.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from werkzeug>=1.0.1->tb-nightly->basicsr) (2.1.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from sympy->torch>=1.7->basicsr) (1.3.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tb-nightly->basicsr) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tb-nightly->basicsr) (3.2.2)
# Requirement already satisfied: facexlib in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (0.3.0)
# Requirement already satisfied: filterpy in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from facexlib) (1.4.5)
# Requirement already satisfied: numba in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from facexlib) (0.58.1)
# Requirement already satisfied: numpy in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from facexlib) (1.24.4)
# Requirement already satisfied: opencv-python in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from facexlib) (4.10.0.84)
# Requirement already satisfied: Pillow in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from facexlib) (10.4.0)
# Requirement already satisfied: scipy in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from facexlib) (1.10.1)
# Requirement already satisfied: torch in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from facexlib) (2.0.1+cu118)
# Requirement already satisfied: torchvision in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from facexlib) (0.15.2+cu118)
# Requirement already satisfied: tqdm in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from facexlib) (4.66.5)
# Requirement already satisfied: matplotlib in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from filterpy->facexlib) (3.7.5)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from numba->facexlib) (0.41.1)
# Requirement already satisfied: importlib-metadata in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from numba->facexlib) (7.0.1)
# Requirement already satisfied: filelock in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from torch->facexlib) (3.16.1)
# Requirement already satisfied: typing-extensions in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from torch->facexlib) (4.11.0)
# Requirement already satisfied: sympy in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from torch->facexlib) (1.13.3)
# Requirement already satisfied: networkx in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from torch->facexlib) (3.1)
# Requirement already satisfied: jinja2 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from torch->facexlib) (3.1.4)
# Requirement already satisfied: requests in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from torchvision->facexlib) (2.32.3)
# Requirement already satisfied: colorama in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from tqdm->facexlib) (0.4.6)
# Requirement already satisfied: zipp>=0.5 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from importlib-metadata->numba->facexlib) (3.20.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from jinja2->torch->facexlib) (2.1.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from matplotlib->filterpy->facexlib) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from matplotlib->filterpy->facexlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from matplotlib->filterpy->facexlib) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from matplotlib->filterpy->facexlib) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from matplotlib->filterpy->facexlib) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from matplotlib->filterpy->facexlib) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from matplotlib->filterpy->facexlib) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from matplotlib->filterpy->facexlib) (6.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from requests->torchvision->facexlib) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from requests->torchvision->facexlib) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from requests->torchvision->facexlib) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from requests->torchvision->facexlib) (2024.8.30)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from sympy->torch->facexlib) (1.3.0)
# Requirement already satisfied: six>=1.5 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from python-dateutil>=2.7->matplotlib->filterpy->facexlib) (1.16.0)
# Requirement already satisfied: gfpgan in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (1.3.8)
# Requirement already satisfied: basicsr>=1.4.2 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from gfpgan) (1.4.2)
# Requirement already satisfied: facexlib>=0.2.5 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from gfpgan) (0.3.0)
# Requirement already satisfied: lmdb in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from gfpgan) (1.5.1)
# Requirement already satisfied: numpy in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from gfpgan) (1.24.4)
# Requirement already satisfied: opencv-python in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from gfpgan) (4.10.0.84)
# Requirement already satisfied: pyyaml in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from gfpgan) (6.0.2)
# Requirement already satisfied: scipy in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from gfpgan) (1.10.1)
# Requirement already satisfied: tb-nightly in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from gfpgan) (2.14.0a20230808)
# Requirement already satisfied: torch>=1.7 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from gfpgan) (2.0.1+cu118)
# Requirement already satisfied: torchvision in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from gfpgan) (0.15.2+cu118)
# Requirement already satisfied: tqdm in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from gfpgan) (4.66.5)
# Requirement already satisfied: yapf in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from gfpgan) (0.40.2)
# Requirement already satisfied: addict in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from basicsr>=1.4.2->gfpgan) (2.4.0)
# Requirement already satisfied: future in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from basicsr>=1.4.2->gfpgan) (1.0.0)
# Requirement already satisfied: Pillow in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from basicsr>=1.4.2->gfpgan) (10.4.0)
# Requirement already satisfied: requests in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from basicsr>=1.4.2->gfpgan) (2.32.3)
# Requirement already satisfied: scikit-image in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from basicsr>=1.4.2->gfpgan) (0.21.0)
# Requirement already satisfied: filterpy in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from facexlib>=0.2.5->gfpgan) (1.4.5)
# Requirement already satisfied: numba in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from facexlib>=0.2.5->gfpgan) (0.58.1)
# Requirement already satisfied: filelock in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from torch>=1.7->gfpgan) (3.16.1)
# Requirement already satisfied: typing-extensions in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from torch>=1.7->gfpgan) (4.11.0)
# Requirement already satisfied: sympy in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from torch>=1.7->gfpgan) (1.13.3)
# Requirement already satisfied: networkx in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from torch>=1.7->gfpgan) (3.1)
# Requirement already satisfied: jinja2 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from torch>=1.7->gfpgan) (3.1.4)
# Requirement already satisfied: absl-py>=0.4 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from tb-nightly->gfpgan) (2.1.0)
# Requirement already satisfied: grpcio>=1.48.2 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from tb-nightly->gfpgan) (1.67.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from tb-nightly->gfpgan) (2.35.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from tb-nightly->gfpgan) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from tb-nightly->gfpgan) (3.7)
# Requirement already satisfied: protobuf>=3.19.6 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from tb-nightly->gfpgan) (5.28.2)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from tb-nightly->gfpgan) (75.1.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from tb-nightly->gfpgan) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from tb-nightly->gfpgan) (3.0.4)
# Requirement already satisfied: wheel>=0.26 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from tb-nightly->gfpgan) (0.44.0)
# Requirement already satisfied: colorama in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from tqdm->gfpgan) (0.4.6)
# Requirement already satisfied: importlib-metadata>=6.6.0 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from yapf->gfpgan) (7.0.1)
# Requirement already satisfied: platformdirs>=3.5.1 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from yapf->gfpgan) (3.10.0)
# Requirement already satisfied: tomli>=2.0.1 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from yapf->gfpgan) (2.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from google-auth<3,>=1.6.3->tb-nightly->gfpgan) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from google-auth<3,>=1.6.3->tb-nightly->gfpgan) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from google-auth<3,>=1.6.3->tb-nightly->gfpgan) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from google-auth-oauthlib<1.1,>=0.5->tb-nightly->gfpgan) (2.0.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from importlib-metadata>=6.6.0->yapf->gfpgan) (3.20.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from requests->basicsr>=1.4.2->gfpgan) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from requests->basicsr>=1.4.2->gfpgan) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from requests->basicsr>=1.4.2->gfpgan) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from requests->basicsr>=1.4.2->gfpgan) (2024.8.30)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from werkzeug>=1.0.1->tb-nightly->gfpgan) (2.1.3)
# Requirement already satisfied: matplotlib in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from filterpy->facexlib>=0.2.5->gfpgan) (3.7.5)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from numba->facexlib>=0.2.5->gfpgan) (0.41.1)
# Requirement already satisfied: imageio>=2.27 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from scikit-image->basicsr>=1.4.2->gfpgan) (2.35.1)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from scikit-image->basicsr>=1.4.2->gfpgan) (2023.7.10)
# Requirement already satisfied: PyWavelets>=1.1.1 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from scikit-image->basicsr>=1.4.2->gfpgan) (1.4.1)
# Requirement already satisfied: packaging>=21 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from scikit-image->basicsr>=1.4.2->gfpgan) (24.1)
# Requirement already satisfied: lazy_loader>=0.2 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from scikit-image->basicsr>=1.4.2->gfpgan) (0.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from sympy->torch>=1.7->gfpgan) (1.3.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tb-nightly->gfpgan) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tb-nightly->gfpgan) (3.2.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from matplotlib->filterpy->facexlib>=0.2.5->gfpgan) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from matplotlib->filterpy->facexlib>=0.2.5->gfpgan) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from matplotlib->filterpy->facexlib>=0.2.5->gfpgan) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from matplotlib->filterpy->facexlib>=0.2.5->gfpgan) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from matplotlib->filterpy->facexlib>=0.2.5->gfpgan) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from matplotlib->filterpy->facexlib>=0.2.5->gfpgan) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from matplotlib->filterpy->facexlib>=0.2.5->gfpgan) (6.4.0)
# Requirement already satisfied: six>=1.5 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from python-dateutil>=2.7->matplotlib->filterpy->facexlib>=0.2.5->gfpgan) (1.16.0)
# Requirement already satisfied: basicsr>=1.4.2 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from -r requirements.txt (line 1)) (1.4.2)
# Requirement already satisfied: facexlib>=0.2.5 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from -r requirements.txt (line 2)) (0.3.0)
# Requirement already satisfied: gfpgan>=1.3.5 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from -r requirements.txt (line 3)) (1.3.8)
# Requirement already satisfied: numpy in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from -r requirements.txt (line 4)) (1.24.4)
# Requirement already satisfied: opencv-python in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from -r requirements.txt (line 5)) (4.10.0.84)
# Requirement already satisfied: Pillow in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from -r requirements.txt (line 6)) (10.4.0)
# Requirement already satisfied: torch>=1.7 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from -r requirements.txt (line 7)) (2.0.1+cu118)
# Requirement already satisfied: torchvision in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from -r requirements.txt (line 8)) (0.15.2+cu118)
# Requirement already satisfied: tqdm in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from -r requirements.txt (line 9)) (4.66.5)
# Requirement already satisfied: addict in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from basicsr>=1.4.2->-r requirements.txt (line 1)) (2.4.0)
# Requirement already satisfied: future in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from basicsr>=1.4.2->-r requirements.txt (line 1)) (1.0.0)
# Requirement already satisfied: lmdb in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from basicsr>=1.4.2->-r requirements.txt (line 1)) (1.5.1)
# Requirement already satisfied: pyyaml in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from basicsr>=1.4.2->-r requirements.txt (line 1)) (6.0.2)
# Requirement already satisfied: requests in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from basicsr>=1.4.2->-r requirements.txt (line 1)) (2.32.3)
# Requirement already satisfied: scikit-image in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from basicsr>=1.4.2->-r requirements.txt (line 1)) (0.21.0)
# Requirement already satisfied: scipy in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from basicsr>=1.4.2->-r requirements.txt (line 1)) (1.10.1)
# Requirement already satisfied: tb-nightly in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from basicsr>=1.4.2->-r requirements.txt (line 1)) (2.14.0a20230808)
# Requirement already satisfied: yapf in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from basicsr>=1.4.2->-r requirements.txt (line 1)) (0.40.2)
# Requirement already satisfied: filterpy in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from facexlib>=0.2.5->-r requirements.txt (line 2)) (1.4.5)
# Requirement already satisfied: numba in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from facexlib>=0.2.5->-r requirements.txt (line 2)) (0.58.1)
# Requirement already satisfied: filelock in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from torch>=1.7->-r requirements.txt (line 7)) (3.16.1)
# Requirement already satisfied: typing-extensions in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from torch>=1.7->-r requirements.txt (line 7)) (4.11.0)
# Requirement already satisfied: sympy in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from torch>=1.7->-r requirements.txt (line 7)) (1.13.3)
# Requirement already satisfied: networkx in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from torch>=1.7->-r requirements.txt (line 7)) (3.1)
# Requirement already satisfied: jinja2 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from torch>=1.7->-r requirements.txt (line 7)) (3.1.4)
# Requirement already satisfied: colorama in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from tqdm->-r requirements.txt (line 9)) (0.4.6)
# Requirement already satisfied: matplotlib in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from filterpy->facexlib>=0.2.5->-r requirements.txt (line 2)) (3.7.5)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from jinja2->torch>=1.7->-r requirements.txt (line 7)) (2.1.3)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from numba->facexlib>=0.2.5->-r requirements.txt (line 2)) (0.41.1)
# Requirement already satisfied: importlib-metadata in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from numba->facexlib>=0.2.5->-r requirements.txt (line 2)) (7.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from requests->basicsr>=1.4.2->-r requirements.txt (line 1)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from requests->basicsr>=1.4.2->-r requirements.txt (line 1)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from requests->basicsr>=1.4.2->-r requirements.txt (line 1)) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from requests->basicsr>=1.4.2->-r requirements.txt (line 1)) (2024.8.30)
# Requirement already satisfied: imageio>=2.27 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from scikit-image->basicsr>=1.4.2->-r requirements.txt (line 1)) (2.35.1)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from scikit-image->basicsr>=1.4.2->-r requirements.txt (line 1)) (2023.7.10)
# Requirement already satisfied: PyWavelets>=1.1.1 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from scikit-image->basicsr>=1.4.2->-r requirements.txt (line 1)) (1.4.1)
# Requirement already satisfied: packaging>=21 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from scikit-image->basicsr>=1.4.2->-r requirements.txt (line 1)) (24.1)
# Requirement already satisfied: lazy_loader>=0.2 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from scikit-image->basicsr>=1.4.2->-r requirements.txt (line 1)) (0.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from sympy->torch>=1.7->-r requirements.txt (line 7)) (1.3.0)
# Requirement already satisfied: absl-py>=0.4 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from tb-nightly->basicsr>=1.4.2->-r requirements.txt (line 1)) (2.1.0)
# Requirement already satisfied: grpcio>=1.48.2 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from tb-nightly->basicsr>=1.4.2->-r requirements.txt (line 1)) (1.67.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from tb-nightly->basicsr>=1.4.2->-r requirements.txt (line 1)) (2.35.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from tb-nightly->basicsr>=1.4.2->-r requirements.txt (line 1)) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from tb-nightly->basicsr>=1.4.2->-r requirements.txt (line 1)) (3.7)
# Requirement already satisfied: protobuf>=3.19.6 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from tb-nightly->basicsr>=1.4.2->-r requirements.txt (line 1)) (5.28.2)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from tb-nightly->basicsr>=1.4.2->-r requirements.txt (line 1)) (75.1.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from tb-nightly->basicsr>=1.4.2->-r requirements.txt (line 1)) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from tb-nightly->basicsr>=1.4.2->-r requirements.txt (line 1)) (3.0.4)
# Requirement already satisfied: wheel>=0.26 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from tb-nightly->basicsr>=1.4.2->-r requirements.txt (line 1)) (0.44.0)
# Requirement already satisfied: platformdirs>=3.5.1 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from yapf->basicsr>=1.4.2->-r requirements.txt (line 1)) (3.10.0)
# Requirement already satisfied: tomli>=2.0.1 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from yapf->basicsr>=1.4.2->-r requirements.txt (line 1)) (2.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from google-auth<3,>=1.6.3->tb-nightly->basicsr>=1.4.2->-r requirements.txt (line 1)) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from google-auth<3,>=1.6.3->tb-nightly->basicsr>=1.4.2->-r requirements.txt (line 1)) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from google-auth<3,>=1.6.3->tb-nightly->basicsr>=1.4.2->-r requirements.txt (line 1)) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from google-auth-oauthlib<1.1,>=0.5->tb-nightly->basicsr>=1.4.2->-r requirements.txt (line 1)) (2.0.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from importlib-metadata->numba->facexlib>=0.2.5->-r requirements.txt (line 2)) (3.20.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from matplotlib->filterpy->facexlib>=0.2.5->-r requirements.txt (line 2)) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from matplotlib->filterpy->facexlib>=0.2.5->-r requirements.txt (line 2)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from matplotlib->filterpy->facexlib>=0.2.5->-r requirements.txt (line 2)) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from matplotlib->filterpy->facexlib>=0.2.5->-r requirements.txt (line 2)) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from matplotlib->filterpy->facexlib>=0.2.5->-r requirements.txt (line 2)) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from matplotlib->filterpy->facexlib>=0.2.5->-r requirements.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from matplotlib->filterpy->facexlib>=0.2.5->-r requirements.txt (line 2)) (6.4.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tb-nightly->basicsr>=1.4.2->-r requirements.txt (line 1)) (0.6.1)
# Requirement already satisfied: six>=1.5 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from python-dateutil>=2.7->matplotlib->filterpy->facexlib>=0.2.5->-r requirements.txt (line 2)) (1.16.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tb-nightly->basicsr>=1.4.2->-r requirements.txt (line 1)) (3.2.2)
# running develop
# running egg_info
# writing realesrgan.egg-info\PKG-INFO
# writing dependency_links to realesrgan.egg-info\dependency_links.txt
# writing requirements to realesrgan.egg-info\requires.txt
# writing top-level names to realesrgan.egg-info\top_level.txt
# reading manifest file 'realesrgan.egg-info\SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# adding license file 'LICENSE'
# writing manifest file 'realesrgan.egg-info\SOURCES.txt'
# running build_ext
# Creating c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages\realesrgan.egg-link (link to .)
# Removing realesrgan 0.3.0 from easy-install.pth file
# realesrgan 0.3.0 is already the active version in easy-install.pth
# detected new path 'c:\\users\\lamch\\repo\\so-upz\\deploy\\real-esrgan'
#
# Installed c:\users\lamch\repo\real-esrgan
# Processing dependencies for realesrgan==0.3.0
# Searching for tqdm==4.66.5
# Best match: tqdm 4.66.5
# Adding tqdm 4.66.5 to easy-install.pth file
# Installing tqdm-script.py script to C:\Users\lamch\miniconda3\envs\ersgan\Scripts
# Installing tqdm.exe script to C:\Users\lamch\miniconda3\envs\ersgan\Scripts
#
# Using c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages
# Searching for torchvision==0.15.2+cu118
# Best match: torchvision 0.15.2+cu118
# Adding torchvision 0.15.2+cu118 to easy-install.pth file
#
# Using c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages
# Searching for torch==2.0.1+cu118
# Best match: torch 2.0.1+cu118
# Adding torch 2.0.1+cu118 to easy-install.pth file
# Installing convert-caffe2-to-onnx-script.py script to C:\Users\lamch\miniconda3\envs\ersgan\Scripts
# Installing convert-caffe2-to-onnx.exe script to C:\Users\lamch\miniconda3\envs\ersgan\Scripts
# Installing convert-onnx-to-caffe2-script.py script to C:\Users\lamch\miniconda3\envs\ersgan\Scripts
# Installing convert-onnx-to-caffe2.exe script to C:\Users\lamch\miniconda3\envs\ersgan\Scripts
# Installing torchrun-script.py script to C:\Users\lamch\miniconda3\envs\ersgan\Scripts
# Installing torchrun.exe script to C:\Users\lamch\miniconda3\envs\ersgan\Scripts
#
# Using c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages
# Searching for pillow==10.4.0
# Best match: pillow 10.4.0
# Adding pillow 10.4.0 to easy-install.pth file
#
# Using c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages
# Searching for opencv-python==4.10.0.84
# Best match: opencv-python 4.10.0.84
# Adding opencv-python 4.10.0.84 to easy-install.pth file
#
# Using c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages
# Searching for numpy==1.24.4
# Best match: numpy 1.24.4
# Adding numpy 1.24.4 to easy-install.pth file
# Installing f2py-script.py script to C:\Users\lamch\miniconda3\envs\ersgan\Scripts
# Installing f2py.exe script to C:\Users\lamch\miniconda3\envs\ersgan\Scripts
#
# Using c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages
# Searching for gfpgan==1.3.8
# Best match: gfpgan 1.3.8
# Adding gfpgan 1.3.8 to easy-install.pth file
#
# Using c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages
# Searching for facexlib==0.3.0
# Best match: facexlib 0.3.0
# Adding facexlib 0.3.0 to easy-install.pth file
#
# Using c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages
# Searching for basicsr==1.4.2
# Best match: basicsr 1.4.2
# Adding basicsr 1.4.2 to easy-install.pth file
#
# Using c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages
# Searching for colorama==0.4.6
# Best match: colorama 0.4.6
# Adding colorama 0.4.6 to easy-install.pth file
#
# Using c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages
# Searching for requests==2.32.3
# Best match: requests 2.32.3
# Adding requests 2.32.3 to easy-install.pth file
#
# Using c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages
# Searching for jinja2==3.1.4
# Best match: jinja2 3.1.4
# Adding jinja2 3.1.4 to easy-install.pth file
#
# Using c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages
# Searching for networkx==3.1
# Best match: networkx 3.1
# Adding networkx 3.1 to easy-install.pth file
#
# Using c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages
# Searching for sympy==1.13.3
# Best match: sympy 1.13.3
# Adding sympy 1.13.3 to easy-install.pth file
# Installing isympy-script.py script to C:\Users\lamch\miniconda3\envs\ersgan\Scripts
# Installing isympy.exe script to C:\Users\lamch\miniconda3\envs\ersgan\Scripts
#
# Using c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages
# Searching for typing-extensions==4.12.2
# Best match: typing-extensions 4.12.2
# Adding typing-extensions 4.12.2 to easy-install.pth file
#
# Using c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages\setuptools\_vendor
# Searching for filelock==3.16.1
# Best match: filelock 3.16.1
# Adding filelock 3.16.1 to easy-install.pth file
#
# Using c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages
# Searching for yapf==0.40.2
# Best match: yapf 0.40.2
# Adding yapf 0.40.2 to easy-install.pth file
# Installing yapf-script.py script to C:\Users\lamch\miniconda3\envs\ersgan\Scripts
# Installing yapf.exe script to C:\Users\lamch\miniconda3\envs\ersgan\Scripts
# Installing yapf-diff-script.py script to C:\Users\lamch\miniconda3\envs\ersgan\Scripts
# Installing yapf-diff.exe script to C:\Users\lamch\miniconda3\envs\ersgan\Scripts
#
# Using c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages
# Searching for tb-nightly==2.14.0a20230808
# Best match: tb-nightly 2.14.0a20230808
# Adding tb-nightly 2.14.0a20230808 to easy-install.pth file
# Installing tensorboard-script.py script to C:\Users\lamch\miniconda3\envs\ersgan\Scripts
# Installing tensorboard.exe script to C:\Users\lamch\miniconda3\envs\ersgan\Scripts
#
# Using c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages
# Searching for scipy==1.10.1
# Best match: scipy 1.10.1
# Adding scipy 1.10.1 to easy-install.pth file
#
# Using c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages
# Searching for PyYAML==6.0.2
# Best match: PyYAML 6.0.2
# Adding PyYAML 6.0.2 to easy-install.pth file
#
# Using c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages
# Searching for lmdb==1.5.1
# Best match: lmdb 1.5.1
# Adding lmdb 1.5.1 to easy-install.pth file
#
# Using c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages
# Searching for numba==0.58.1
# Best match: numba 0.58.1
# Adding numba 0.58.1 to easy-install.pth file
#
# Using c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages
# Searching for filterpy==1.4.5
# Best match: filterpy 1.4.5
# Adding filterpy 1.4.5 to easy-install.pth file
#
# Using c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages
# Searching for scikit-image==0.21.0
# Best match: scikit-image 0.21.0
# Adding scikit-image 0.21.0 to easy-install.pth file
#
# Using c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages
# Searching for future==1.0.0
# Best match: future 1.0.0
# Adding future 1.0.0 to easy-install.pth file
# Installing futurize-script.py script to C:\Users\lamch\miniconda3\envs\ersgan\Scripts
# Installing futurize.exe script to C:\Users\lamch\miniconda3\envs\ersgan\Scripts
# Installing pasteurize-script.py script to C:\Users\lamch\miniconda3\envs\ersgan\Scripts
# Installing pasteurize.exe script to C:\Users\lamch\miniconda3\envs\ersgan\Scripts
#
# Using c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages
# Searching for addict==2.4.0
# Best match: addict 2.4.0
# Adding addict 2.4.0 to easy-install.pth file
#
# Using c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages
# Searching for certifi==2024.8.30
# Best match: certifi 2024.8.30
# Adding certifi 2024.8.30 to easy-install.pth file
#
# Using c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages
# Searching for urllib3==2.2.3
# Best match: urllib3 2.2.3
# Adding urllib3 2.2.3 to easy-install.pth file
#
# Using c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages
# Searching for idna==3.10
# Best match: idna 3.10
# Adding idna 3.10 to easy-install.pth file
#
# Using c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages
# Searching for charset-normalizer==3.4.0
# Best match: charset-normalizer 3.4.0
# Adding charset-normalizer 3.4.0 to easy-install.pth file
# Installing normalizer-script.py script to C:\Users\lamch\miniconda3\envs\ersgan\Scripts
# Installing normalizer.exe script to C:\Users\lamch\miniconda3\envs\ersgan\Scripts
#
# Using c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages
# Searching for MarkupSafe==2.1.5
# Best match: MarkupSafe 2.1.5
# Adding MarkupSafe 2.1.5 to easy-install.pth file
#
# Using c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages
# Searching for mpmath==1.3.0
# Best match: mpmath 1.3.0
# Adding mpmath 1.3.0 to easy-install.pth file
#
# Using c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages
# Searching for tomli==2.0.2
# Best match: tomli 2.0.2
# Adding tomli 2.0.2 to easy-install.pth file
#
# Using c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages
# Searching for platformdirs==4.3.6
# Best match: platformdirs 4.3.6
# Adding platformdirs 4.3.6 to easy-install.pth file
#
# Using c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages
# Searching for importlib-metadata==8.5.0
# Best match: importlib-metadata 8.5.0
# Adding importlib-metadata 8.5.0 to easy-install.pth file
#
# Using c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages
# Searching for wheel==0.44.0
# Best match: wheel 0.44.0
# Adding wheel 0.44.0 to easy-install.pth file
# Installing wheel-script.py script to C:\Users\lamch\miniconda3\envs\ersgan\Scripts
# Installing wheel.exe script to C:\Users\lamch\miniconda3\envs\ersgan\Scripts
#
# Using c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages
# Searching for werkzeug==3.0.4
# Best match: werkzeug 3.0.4
# Adding werkzeug 3.0.4 to easy-install.pth file
#
# Using c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages
# Searching for tensorboard-data-server==0.7.2
# Best match: tensorboard-data-server 0.7.2
# Adding tensorboard-data-server 0.7.2 to easy-install.pth file
#
# Using c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages
# Searching for setuptools==75.1.0
# Best match: setuptools 75.1.0
# Adding setuptools 75.1.0 to easy-install.pth file
#
# Using c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages
# Searching for protobuf==5.28.2
# Best match: protobuf 5.28.2
# Adding protobuf 5.28.2 to easy-install.pth file
#
# Using c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages
# Searching for Markdown==3.7
# Best match: Markdown 3.7
# Adding Markdown 3.7 to easy-install.pth file
# Installing markdown_py-script.py script to C:\Users\lamch\miniconda3\envs\ersgan\Scripts
# Installing markdown_py.exe script to C:\Users\lamch\miniconda3\envs\ersgan\Scripts
#
# Using c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages
# Searching for google-auth-oauthlib==1.0.0
# Best match: google-auth-oauthlib 1.0.0
# Adding google-auth-oauthlib 1.0.0 to easy-install.pth file
# Installing google-oauthlib-tool-script.py script to C:\Users\lamch\miniconda3\envs\ersgan\Scripts
# Installing google-oauthlib-tool.exe script to C:\Users\lamch\miniconda3\envs\ersgan\Scripts
#
# Using c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages
# Searching for google-auth==2.35.0
# Best match: google-auth 2.35.0
# Adding google-auth 2.35.0 to easy-install.pth file
#
# Using c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages
# Searching for grpcio==1.67.0
# Best match: grpcio 1.67.0
# Adding grpcio 1.67.0 to easy-install.pth file
#
# Using c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages
# Searching for absl-py==2.1.0
# Best match: absl-py 2.1.0
# Adding absl-py 2.1.0 to easy-install.pth file
#
# Using c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages
# Searching for llvmlite==0.41.1
# Best match: llvmlite 0.41.1
# Adding llvmlite 0.41.1 to easy-install.pth file
#
# Using c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages
# Searching for matplotlib==3.7.5
# Best match: matplotlib 3.7.5
# Adding matplotlib 3.7.5 to easy-install.pth file
#
# Using c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages
# Searching for lazy-loader==0.4
# Best match: lazy-loader 0.4
# Adding lazy-loader 0.4 to easy-install.pth file
#
# Using c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages
# Searching for packaging==24.1
# Best match: packaging 24.1
# packaging 24.1 is already the active version in easy-install.pth
#
# Using c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages\setuptools\_vendor
# Searching for PyWavelets==1.4.1
# Best match: PyWavelets 1.4.1
# Adding PyWavelets 1.4.1 to easy-install.pth file
#
# Using c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages
# Searching for tifffile==2023.7.10
# Best match: tifffile 2023.7.10
# Adding tifffile 2023.7.10 to easy-install.pth file
# Installing lsm2bin-script.py script to C:\Users\lamch\miniconda3\envs\ersgan\Scripts
# Installing lsm2bin.exe script to C:\Users\lamch\miniconda3\envs\ersgan\Scripts
# Installing tiff2fsspec-script.py script to C:\Users\lamch\miniconda3\envs\ersgan\Scripts
# Installing tiff2fsspec.exe script to C:\Users\lamch\miniconda3\envs\ersgan\Scripts
# Installing tiffcomment-script.py script to C:\Users\lamch\miniconda3\envs\ersgan\Scripts
# Installing tiffcomment.exe script to C:\Users\lamch\miniconda3\envs\ersgan\Scripts
# Installing tifffile-script.py script to C:\Users\lamch\miniconda3\envs\ersgan\Scripts
# Installing tifffile.exe script to C:\Users\lamch\miniconda3\envs\ersgan\Scripts
#
# Using c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages
# Searching for imageio==2.35.1
# Best match: imageio 2.35.1
# Adding imageio 2.35.1 to easy-install.pth file
# Installing imageio_download_bin-script.py script to C:\Users\lamch\miniconda3\envs\ersgan\Scripts
# Installing imageio_download_bin.exe script to C:\Users\lamch\miniconda3\envs\ersgan\Scripts
# Installing imageio_remove_bin-script.py script to C:\Users\lamch\miniconda3\envs\ersgan\Scripts
# Installing imageio_remove_bin.exe script to C:\Users\lamch\miniconda3\envs\ersgan\Scripts
#
# Using c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages
# Searching for zipp==3.20.2
# Best match: zipp 3.20.2
# Adding zipp 3.20.2 to easy-install.pth file
#
# Using c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages
# Searching for requests-oauthlib==2.0.0
# Best match: requests-oauthlib 2.0.0
# Adding requests-oauthlib 2.0.0 to easy-install.pth file
#
# Using c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages
# Searching for rsa==4.9
# Best match: rsa 4.9
# Adding rsa 4.9 to easy-install.pth file
# Installing pyrsa-decrypt-script.py script to C:\Users\lamch\miniconda3\envs\ersgan\Scripts
# Installing pyrsa-decrypt.exe script to C:\Users\lamch\miniconda3\envs\ersgan\Scripts
# Installing pyrsa-encrypt-script.py script to C:\Users\lamch\miniconda3\envs\ersgan\Scripts
# Installing pyrsa-encrypt.exe script to C:\Users\lamch\miniconda3\envs\ersgan\Scripts
# Installing pyrsa-keygen-script.py script to C:\Users\lamch\miniconda3\envs\ersgan\Scripts
# Installing pyrsa-keygen.exe script to C:\Users\lamch\miniconda3\envs\ersgan\Scripts
# Installing pyrsa-priv2pub-script.py script to C:\Users\lamch\miniconda3\envs\ersgan\Scripts
# Installing pyrsa-priv2pub.exe script to C:\Users\lamch\miniconda3\envs\ersgan\Scripts
# Installing pyrsa-sign-script.py script to C:\Users\lamch\miniconda3\envs\ersgan\Scripts
# Installing pyrsa-sign.exe script to C:\Users\lamch\miniconda3\envs\ersgan\Scripts
# Installing pyrsa-verify-script.py script to C:\Users\lamch\miniconda3\envs\ersgan\Scripts
# Installing pyrsa-verify.exe script to C:\Users\lamch\miniconda3\envs\ersgan\Scripts
#
# Using c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages
# Searching for pyasn1-modules==0.4.1
# Best match: pyasn1-modules 0.4.1
# Adding pyasn1-modules 0.4.1 to easy-install.pth file
#
# Using c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages
# Searching for cachetools==5.5.0
# Best match: cachetools 5.5.0
# Adding cachetools 5.5.0 to easy-install.pth file
#
# Using c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages
# Searching for importlib-resources==6.4.5
# Best match: importlib-resources 6.4.5
# Adding importlib-resources 6.4.5 to easy-install.pth file
#
# Using c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages
# Searching for python-dateutil==2.9.0.post0
# Best match: python-dateutil 2.9.0.post0
# Adding python-dateutil 2.9.0.post0 to easy-install.pth file
#
# Using c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages
# Searching for pyparsing==3.1.4
# Best match: pyparsing 3.1.4
# Adding pyparsing 3.1.4 to easy-install.pth file
#
# Using c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages
# Searching for kiwisolver==1.4.7
# Best match: kiwisolver 1.4.7
# Adding kiwisolver 1.4.7 to easy-install.pth file
#
# Using c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages
# Searching for fonttools==4.54.1
# Best match: fonttools 4.54.1
# Adding fonttools 4.54.1 to easy-install.pth file
# Installing fonttools-script.py script to C:\Users\lamch\miniconda3\envs\ersgan\Scripts
# Installing fonttools.exe script to C:\Users\lamch\miniconda3\envs\ersgan\Scripts
# Installing pyftmerge-script.py script to C:\Users\lamch\miniconda3\envs\ersgan\Scripts
# Installing pyftmerge.exe script to C:\Users\lamch\miniconda3\envs\ersgan\Scripts
# Installing pyftsubset-script.py script to C:\Users\lamch\miniconda3\envs\ersgan\Scripts
# Installing pyftsubset.exe script to C:\Users\lamch\miniconda3\envs\ersgan\Scripts
# Installing ttx-script.py script to C:\Users\lamch\miniconda3\envs\ersgan\Scripts
# Installing ttx.exe script to C:\Users\lamch\miniconda3\envs\ersgan\Scripts
#
# Using c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages
# Searching for cycler==0.12.1
# Best match: cycler 0.12.1
# Adding cycler 0.12.1 to easy-install.pth file
#
# Using c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages
# Searching for contourpy==1.1.1
# Best match: contourpy 1.1.1
# Adding contourpy 1.1.1 to easy-install.pth file
#
# Using c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages
# Searching for oauthlib==3.2.2
# Best match: oauthlib 3.2.2
# Adding oauthlib 3.2.2 to easy-install.pth file
#
# Using c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages
# Searching for pyasn1==0.6.1
# Best match: pyasn1 0.6.1
# Adding pyasn1 0.6.1 to easy-install.pth file
#
# Using c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages
# Searching for six==1.16.0
# Best match: six 1.16.0
# Adding six 1.16.0 to easy-install.pth file
#
# Using c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages
# Finished processing dependencies for realesrgan==0.3.0
# C:\Users\lamch\miniconda3\envs\ersgan\lib\site-packages\setuptools\__init__.py:94: _DeprecatedInstaller: setuptools.installer and fetch_build_eggs are deprecated.
# !!
#
#         ********************************************************************************
#         Requirements should be satisfied by a PEP 517 installer.
#         If you are using pip, you can try `pip install --use-pep517`.
#         ********************************************************************************
#
# !!
#   dist.fetch_build_eggs(dist.setup_requires)
# C:\Users\lamch\miniconda3\envs\ersgan\lib\site-packages\setuptools\command\develop.py:41: EasyInstallDeprecationWarning: easy_install command is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` and ``easy_install``.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://github.com/pypa/setuptools/issues/917 for details.
#         ********************************************************************************
#
# !!
#   easy_install.initialize_options(self)
# C:\Users\lamch\miniconda3\envs\ersgan\lib\site-packages\setuptools\_distutils\cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu118
# Requirement already satisfied: torch==2.0.1 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (2.0.1+cu118)
# Requirement already satisfied: torchvision==0.15.2 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (0.15.2+cu118)
# Requirement already satisfied: filelock in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from torch==2.0.1) (3.16.1)
# Requirement already satisfied: typing-extensions in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from torch==2.0.1) (4.11.0)
# Requirement already satisfied: sympy in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from torch==2.0.1) (1.13.3)
# Requirement already satisfied: networkx in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from torch==2.0.1) (3.1)
# Requirement already satisfied: jinja2 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from torch==2.0.1) (3.1.4)
# Requirement already satisfied: numpy in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from torchvision==0.15.2) (1.24.4)
# Requirement already satisfied: requests in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from torchvision==0.15.2) (2.32.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from torchvision==0.15.2) (10.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from jinja2->torch==2.0.1) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from requests->torchvision==0.15.2) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from requests->torchvision==0.15.2) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from requests->torchvision==0.15.2) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from requests->torchvision==0.15.2) (2024.8.30)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\lamch\miniconda3\envs\ersgan\lib\site-packages (from sympy->torch==2.0.1) (1.3.0)

# %% [markdown]
# # 2. Upload Images
#
# Upload the images to be processed by Real-ESRGAN

# %%
import os
# from google.colab import files
import shutil

# Create the folders for input and output
upload_folder = 'upload'
result_folder = 'results'

if os.path.isdir(upload_folder):
    shutil.rmtree(upload_folder)
if os.path.isdir(result_folder):
    shutil.rmtree(result_folder)
os.mkdir(upload_folder)
os.mkdir(result_folder)

# upload images
# uploaded = files.upload()
# for filename in uploaded.keys():
#   dst_path = os.path.join(upload_folder, filename)
#   print(f'move {filename} to {dst_path}')
#   shutil.move(filename, dst_path)

# %% [markdown]
# ## Upload Files
# Upload all files into the `/upload` folder

# %% [markdown]
# # 3. Inference

# %%
# if it is out of memory, try to use the `--tile` option
# We upsample the image with the scale factor X3.5
# !python inference_realesrgan.py -n RealESRGAN_x4plus -i upload --outscale 16
# Arguments
# -n, --model_name: Model names
# -i, --input: input folder or image
# --outscale: Output scale, can be arbitrary scale factore.
# Out:
# Testing 0 low-quality-image
# C:\Users\lamch\miniconda3\envs\ersgan\lib\site-packages\torchvision\transforms\functional_tensor.py:5: UserWarning: The torchvision.transforms.functional_tensor module is deprecated in 0.15 and will be **removed in 0.17**. Please don't rely on it. You probably just need to use APIs in torchvision.transforms.functional or in torchvision.transforms.v2.functional.
#   warnings.warn(

# %% [markdown]
# # 4. Visualization

# %%
# utils for visualization
import cv2
import matplotlib.pyplot as plt
def display(img1, img2):
  fig = plt.figure(figsize=(25, 10))
  ax1 = fig.add_subplot(1, 2, 1)
  plt.title('Input image', fontsize=16)
  ax1.axis('off')
  ax2 = fig.add_subplot(1, 2, 2)
  plt.title('Real-ESRGAN output', fontsize=16)
  ax2.axis('off')
  ax1.imshow(img1)
  ax2.imshow(img2)
def imread(img_path):
  img = cv2.imread(img_path)
  img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
  return img

# display each image in the upload folder
import os
import glob

input_folder = 'upload'
result_folder = 'results'
input_list = sorted(glob.glob(os.path.join(input_folder, '*')))
output_list = sorted(glob.glob(os.path.join(result_folder, '*')))
for input_path, output_path in zip(input_list, output_list):
  img_input = imread(input_path)
  img_output = imread(output_path)
  display(img_input, img_output)

# %% [markdown]
# # 5. Download Results

# %%
# Download the results
zip_filename = 'Real-ESRGAN_result.zip'
if os.path.exists(zip_filename):
  os.remove(zip_filename)
os.system(f"zip -r -j {zip_filename} results/*")
files.download(zip_filename)
